# %%
import pandas as pd
from src.map_viz import create_map

# Ver dataset
df = pd.read_csv("../data/locations.csv")
df.head()

# %%
# Generar mapa
create_map("../data/locations.csv", "../exploratory_map.html")
